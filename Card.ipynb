# %%
# Personal Info Card
name = "Divyam Thakur"
age = 25
city = "Harlington, UK"
profession = "Aspiring Data Analyst"
favorite_language = "Python"

print("=" * 34)
print("       PERSONAL INFO CARD")
print("=" * 34)
print("Name       :", name)
print("Age        :", age)
print("City       :", city)
print("Profession :", profession)
print("Loves      :", favorite_language)
print("=" * 34)
# Out:
# ...
#        PERSONAL INFO CARD
# ...
# Name       : Divyam Thakur
# Age        : 25
# City       : Harlington, UK
# Profession : Aspiring Data Analyst
# Loves      : Python
# ...
